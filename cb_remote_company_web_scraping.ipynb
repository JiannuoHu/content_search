# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

import wptools
import wikipedia
import re
import numpy as np

from prefect import task, Flow, Parameter
from prefect.executors import LocalDaskExecutor
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# #### web scrape company name, policy, link, story

# %%
url = 'https://buildremote.co/companies/companies-going-remote-permanently/'
user_agent = 'Mozilla/5.0 (iPad; U; CPU OS 3_2_1 like Mac OS X; en-us) AppleWebKit/531.21.10 (KHTML, like Gecko) Mobile/7B405'

raw = requests.get(url, headers={'User-Agent': user_agent})
content_bs4 = BeautifulSoup(raw.content)

# %%
table_content = content_bs4.find_all('td', class_ = 'wptb-cell')
company_table = [i.get_text() for i in table_content]
company_table = company_table[4:]

# %%
link_content = table_content[7:]

link_list = []
for i, j in enumerate(link_content):
    if i%4 == 0:
        try:
            a_link = j.find(href= True)['href']
        except:
            a_link = ''
        
        link_list.append(a_link)

# %%
name = []
policy = []
story = []

for i, j in enumerate(company_table):
    if i%4 ==0:
        name.append(j.strip())
    elif i%4 == 1:
        policy.append(j)
    elif i%4 ==3:
        story.append(j)

# %%
output = pd.DataFrame()
output['name'] = name
output['policy'] = policy
output['link'] = link_list
output['story'] = story

# %% [markdown]
# #### fetch employee size

# %%
#### use wptools to filter not found + wikipedia.search

def get_wiki_disambiguation(clean_name):
    get_data = wptools.page(clean_name).get()
    if get_data is not None:
        if 'what' in get_data.data.keys():
            if get_data.data['what'] == 'Wikimedia disambiguation page':
                links = get_data.data['links']
                for i in links:
                    check_list = ['name', 'logo', 'type', 'traded_as', 'foundation', 'founded', 'released', 'num_employees', 'num_staff']
                    so = wptools.page(i).get_parse()
                    if 'infobox' in so.data.keys():
                        infobox = so.data['infobox']
                        if infobox is not None:
                            intersection = [value for value in check_list if value in infobox.keys()]
                            if len(intersection) >= 3:
                                break
                        else:
                            infobox = {'error': 'Wikipedia page Not Found'}
                    else:
                            infobox = {'error': 'Wikipedia page Not Found'}

            else:
                so = wptools.page(clean_name).get_parse()
                infobox = so.data['infobox']
        else:
            so = wptools.page(clean_name).get_parse()
            infobox = so.data['infobox']
    
    else:
        infobox = infobox = {'error': 'Wikipedia page Not Found'}

    if infobox is not None:        
        infobox['clean_name'] = clean_name
    else:
        infobox = {'error': 'Wikipedia page Not Found', 'clean_name': clean_name}
    
    return infobox


def get_wiki_suggest(clean_name):
    suggest = wikipedia.search(clean_name)
    if len(suggest)>0:
        suggest_name = suggest[0]
    else:
        suggest_name = clean_name
    return suggest_name



def get_wiki_improve(clean_name):
    try:
        infobox = get_wiki_disambiguation(clean_name)
        return infobox
    except:
        try:
            suggest_name = get_wiki_suggest(clean_name)
            infobox = get_wiki_disambiguation(suggest_name)
            return infobox

        except Exception as exc:
            return {'error': exc, 'clean_name': clean_name}

## employee size
def find_size(df, columnname):
    if 'num_employees' in columnname and df['num_employees'] is not np.nan:
        size = df['num_employees']
        employee_size = size
    elif 'num_staff' in columnname and df['num_staff'] is not np.nan:
        size = df['num_staff']
        employee_size = size
    else:
        employee_size = np.nan
    return employee_size

def process_size(size):
    try:
        size = str(size).replace(',', '')

        match = re.findall(r'\d+', size)
        res = list(map(int, match))
        return res[0]
    except:
        return np.nan

# %%
#utility function for getting flow results
def show_result(flow, run):
    last_task = list(flow.terminal_tasks())[0]
    print(list(flow.terminal_tasks()))
    print(last_task)
    return run.result[last_task].result

def show_dataframe_task(output):
    return pd.DataFrame(output)

def merge_dataframe(df1, df2):
    return pd.concat([df1, df2],axis = 1)

# %%
new_company =  output.rename(columns = {'name':'refined_name'})

with Flow('clean name and get wiki improve1', executor=LocalDaskExecutor()) as wiki_flow_improve1:
    refined_name = Parameter('refined_name')
    result1 = task(get_wiki_improve).map(refined_name)
    task(show_dataframe_task)(result1)

### run on batches to get wiki result

batch_num = int(len(new_company)/600)
for i in range(batch_num):
    globals()['batch_%s' % str(i+1)] = new_company[i*600:(i+1)*600].reset_index(drop=True)
globals()['batch_%s' % str(batch_num+1)] = new_company[(batch_num)*600:].reset_index(drop=True)


for i in range(1, batch_num+2):
    current_batch = globals()['batch_'+str(i)]
    namelist = current_batch[current_batch['refined_name'].notna()]['refined_name'].tolist()
    output = wiki_flow_improve1.run(refined_name = namelist)
    globals()['wiki_res_%s' % str(i)] = show_result(wiki_flow_improve1, output)


res_list = []
for i in range(1, batch_num+2):
    res_list.append(globals()['wiki_res_%s' % str(i)])

wiki_result = pd.concat(res_list).reset_index(drop=True)
# Out:
# [2022-01-20 10:07:32-0500] INFO - prefect.FlowRunner | Beginning Flow run for 'clean name and get wiki improve1'
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'refined_name': Starting task run...
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'refined_name': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve': Starting task run...
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve': Finished task run for task with final state: 'Mapped'
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[1]': Starting task run...
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[0]': Starting task run...
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[10]': Starting task run...
# [2022-01-20 10:07:33-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[11]': Starting task run...
# en.wikipedia.org (query) Twitter
# en.wikipedia.org (query) Nationwide
# en.wikipedia.org (query) Slack
# en.wikipedia.org (query) Quora
# en.wikipedia.org (parse) 223400
# en.wikipedia.org (parse) 1322074
# en.wikipedia.org (parse) 26749224
# en.wikipedia.org (query) Twitter (&plcontinue=9988187|0|Lytro)
# www.wikidata.org (wikidata) Q1904950
# www.wikidata.org (wikidata) Q1216768
# www.wikidata.org (wikidata) Q51711
# www.wikidata.org (labels) Q4167410|P31|P1889|Q37555651|P373
# www.wikidata.org (labels) Q4167410|P31
# en.wikipedia.org (query) Twitter (&plcontinue=9988187|0|Web_appli...
# www.wikidata.org (labels) Q9027|P4411|P31|P2003|P646|Q9035|P3553|...
# en.wikipedia.org (restbase) /page/summary/Slack
# en.wikipedia.org (restbase) /page/summary/Nationwide
# Slack (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(1)> Disambiguation
#   claims: <dict(3)> P31, P1889, P373
#   description: Topics referred to by the same term
#   disambiguation: 25
#   exhtml: <p><b>Slack</b> may refer to:</p>
#   exrest: Slack may refer to:
#   extext: **Slack** may refer to:
#   extract: <p><b>Slack</b> may refer to:</p>
#   iwlinks: <list(3)> https://en.wiktionary.org/wiki/Slack, https:/...
#   label: Slack
#   labels: <dict(5)> Q4167410, P31, P1889, Q37555651, P373
#   length: 1,867
#   links: <list(25)> Andrew Slack, Birchills Power Station, Charlie...
#   modified: <dict(2)> page, wikidata
#   pageid: 223400
#   parsetree: <str(2306)> <root><template><title>Wiktionary</title>...
#   random: Dr. Watson (disambiguation)
#   redirects: <list(2)> {'pageid': 19668015, 'ns': 0, 'title': 'Sla...
#   requests: <list(5)> query, parse, wikidata, labels, restbase
#   title: Slack
#   url: https://en.wikipedia.org/wiki/Slack
#   url_raw: https://en.wikipedia.org/wiki/Slack?action=raw
#   what: Wikimedia disambiguation page
#   wikibase: Q1904950
#   wikidata: <dict(3)> instance of (P31), different from (P1889), C...
#   wikidata_pageid: 1834930
#   wikidata_url: https://www.wikidata.org/wiki/Q1904950
#   wikitext: <str(1824)> {{Wiktionary|Slack|slack|släck}}'''Slack''...
# }
# en.wikipedia.org (parse) Andrew Slack
# Nationwide (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(1)> Disambiguation
#   claims: <dict(1)> P31
#   description: Topics referred to by the same term
#   disambiguation: 15
#   exhtml: <p><b>Nationwide</b> may refer to:</p>
#   exrest: Nationwide may refer to:
#   extext: **Nationwide** may refer to:
#   extract: <p><b>Nationwide</b> may refer to:</p>
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Special:Search...
#   label: Nationwide
#   labels: <dict(2)> Q4167410, P31
#   length: 1,456
#   links: <list(15)> English Football League, Kenyan Nationwide Lea...
#   modified: <dict(2)> page, wikidata
#   pageid: 1322074
#   parsetree: <str(1693)> <root><template><title>wiktionary</title>...
#   random: Orcus (beetle)
#   redirects: <list(2)> {'pageid': 10985362, 'ns': 0, 'title': 'Nat...
#   requests: <list(5)> query, parse, wikidata, labels, restbase
#   title: Nationwide
#   url: https://en.wikipedia.org/wiki/Nationwide
#   url_raw: https://en.wikipedia.org/wiki/Nationwide?action=raw
#   what: Wikimedia disambiguation page
#   wikibase: Q1216768
#   wikidata: <dict(1)> instance of (P31)
#   wikidata_pageid: 1158493
#   wikidata_url: https://www.wikidata.org/wiki/Q1216768
#   wikitext: <str(1418)> {{wiktionary}}'''Nationwide''' may refer t...
# }
# en.wikipedia.org (parse) English Football League
# en.wikipedia.org (parse) 9988187
# Andrew Slack (en) data
# {
#   infobox: <dict(14)> name, birth_name, birth_place, school, ru_po...
#   pageid: 9416539
#   parsetree: <str(13196)> <root><template><title>EngvarB</title><p...
#   requests: <list(1)> parse
#   title: Andrew Slack
#   wikibase: Q2846734
#   wikidata_url: https://www.wikidata.org/wiki/Q2846734
#   wikitext: <str(8897)> {{EngvarB|date=August 2013}}{{Use dmy date...
# }
# en.wikipedia.org (parse) Birchills Power Station
# English Football League (en) data
# {
#   image: <list(0)>
#   infobox: <dict(17)> image, country, other countries, confed, fou...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 14419588
#   parsetree: <str(153595)> <root><template><title>short descriptio...
#   requests: <list(1)> parse
#   title: English Football League
#   wikibase: Q213347
#   wikidata_url: https://www.wikidata.org/wiki/Q213347
#   wikitext: <str(116665)> {{short description|League competition f...
# }
# en.wikipedia.org (parse) Kenyan Nationwide League
# www.wikidata.org (wikidata) Q918
# Birchills Power Station (en) data
# {
#   infobox: <dict(17)> name, coordinates, country, location, status...
#   iwlinks: <list(1)> https://www.wikidata.org/wiki/Q4915741
#   pageid: 20345595
#   parsetree: <str(22016)> <root><template><title>more citations ne...
#   requests: <list(1)> parse
#   title: Birchills Power Station
#   wikibase: Q4915741
#   wikidata_url: https://www.wikidata.org/wiki/Q4915741
#   wikitext: <str(14592)> {{more citations needed|date=October 2018...
# }
# en.wikipedia.org (parse) Charlie Slack
# Kenyan Nationwide League (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Defunct
#   pageid: 33861355
#   parsetree: <str(2521)> <root>The '''Kenyan Nationwide League''' ...
#   requests: <list(1)> parse
#   title: Kenyan Nationwide League
#   wikibase: Q6392855
#   wikidata_url: https://www.wikidata.org/wiki/Q6392855
#   wikitext: <str(2112)> The '''Kenyan Nationwide League''' was the...
# }
# en.wikipedia.org (parse) Nationwide (Australian TV programme)
# Charlie Slack (en) data
# {
#   infobox: <dict(18)> name, position, height_ft, height_in, birth_...
#   pageid: 28451676
#   parsetree: <str(9771)> <root><template><title>short description<...
#   requests: <list(1)> parse
#   title: Charlie Slack
#   wikibase: Q5085517
#   wikidata_url: https://www.wikidata.org/wiki/Q5085517
#   wikitext: <str(6694)> {{short description|American basketball pl...
# }
# Nationwide (Australian TV program) (en) data
# en.wikipedia.org (parse) Church of the SubGenius{
#   pageid: 58880775
#
#   parsetree: <str(2112)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Nationwide (Australian TV program)
#   wikibase: Q60791234
#   wikidata_url: https://www.wikidata.org/wiki/Q60791234
#   wikitext: <str(1426)> {{Use dmy dates|date=July 2019}}{{Use Aust...
# }
# en.wikipedia.org (parse) Nationwide (Irish TV programme)
# www.wikidata.org (labels) Q41689563|P8313|P1792|P6760|P7827|P856|...
# www.wikidata.org (labels) Q5885|P7775|P373|Q150|Q7265244|P9618|Q5...
# en.wikipedia.org (imageinfo) File:Nationwide (RTÉ).png
# Church of the SubGenius (en) data
# {
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 73068
#   parsetree: <str(97495)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Church of the SubGenius
#   wikibase: Q211257
#   wikidata_url: https://www.wikidata.org/wiki/Q211257
#   wikitext: <str(45780)> {{short description|Parody religion creat...
# }
# en.wikipedia.org (parse) Dune
# Nationwide (Irish TV programme) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nationwid...
#   infobox: <dict(19)> name, image, caption, genre, presenter, them...
#   pageid: 3023282
#   parsetree: <str(10429)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Nationwide (Irish TV programme)
#   wikibase: Q3337013
#   wikidata_url: https://www.wikidata.org/wiki/Q3337013
#   wikitext: <str(6810)> {{Short description|RTÉ news documentary s...
# }
# en.wikipedia.org (parse) Nationwide (TV programme)
# Dune (en) data
# {
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 7890
#   parsetree: <str(83720)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Dune
#   wikibase: Q25391
#   wikidata_url: https://www.wikidata.org/wiki/Q25391
#   wikitext: <str(68918)> {{short description|Hill of loose sand bu...
# }
# en.wikipedia.org (restbase) /page/summary/Quora
# en.wikipedia.org (parse) File slack
# en.wikipedia.org (imageinfo) File:Nationwide mandala.jpg
# www.wikidata.org (labels) Q8963141|P17|P7829|Q2005|P50|P1056|Q137...
# Quora (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> Quora, Inc., quora.com
#   assessments: <dict(2)> Companies, Websites
#   claims: <dict(40)> P31, P159, P169, P154, P277, P1454, P1687, P3...
#   description: Question-and-answer platform
#   exhtml: <str(380)> <p><b>Quora</b> is an American social questio...
#   exrest: <str(366)> Quora is an American social question-and-answ...
#   extext: <str(369)> **Quora** () is an American social question-a...
#   extract: <str(425)> <p class="mw-empty-elt"></p><p><b>Quora</b> ...
#   image: <list(2)> {'kind': 'restbase-original', 'width': 343, 'he...
#   infobox: <dict(20)> name, logo, collapsible, collapsetext, scree...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:Q...
#   label: Quora
#   labels: <dict(71)> Q9027, P4411, P31, P2003, P646, Q9035, P3553,...
#   length: 56,241
#   links: <list(119)> $, Adam D'Angelo, Adrián Lamo, AllThingsD, Am...
#   modified: <dict(2)> page, wikidata
#   pageid: 26749224
#   parsetree: <str(73307)> <root><template><title>Short description...
#   random: Reason and Truth
#   redirects: <list(7)> {'pageid': 31222852, 'ns': 0, 'title': 'Quo...
#   requests: <list(6)> query, parse, wikidata, labels, labels, restbase
#   title: Quora
#   url: https://en.wikipedia.org/wiki/Quora
#   url_raw: https://en.wikipedia.org/wiki/Quora?action=raw
#   watchers: 300
#   what: question-and-answer site
#   wikibase: Q51711
#   wikidata: <dict(40)> instance of (P31), headquarters location (P...
#   wikidata_pageid: 53895
#   wikidata_url: https://www.wikidata.org/wiki/Q51711
#   wikitext: <str(55939)> {{Short description|Question-and-answer p...
# }
# en.wikipedia.org (parse) Quora
# Nationwide (TV programme) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nationwid...
#   infobox: <dict(16)> name, image, caption, genre, runtime, creato...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Diana_Gould
#   pageid: 2553328
#   parsetree: <str(17688)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Nationwide (TV programme)
#   wikibase: Q3337012
#   wikidata_url: https://www.wikidata.org/wiki/Q3337012
#   wikitext: <str(12229)> {{short description|British news and curr...
# }
# en.wikipedia.org (parse) Nationwide (album)
# Fragmentation (computing) (en) data
# {
#   infobox: <dict(2)> boxes, count
#   pageid: 3909369
#   parsetree: <str(21443)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: Fragmentation (computing)
#   wikibase: Q1132459
#   wikidata_url: https://www.wikidata.org/wiki/Q1132459
#   wikitext: <str(19344)> {{Short description|Inefficient use of st...
# }
# en.wikipedia.org (parse) George Slack
# [2022-01-20 10:07:36-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[11]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:36-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[12]': Starting task run...
# George Slack (en) data
# {
#   pageid: 46797209
#   parsetree: <str(1928)> <root>'''George W. Slack''' (April 2, 187...
#   requests: <list(1)> parse
#   title: George Slack
#   wikibase: Q19975228
#   wikidata_url: https://www.wikidata.org/wiki/Q19975228
#   wikitext: <str(1495)> '''George W. Slack''' (April 2, 1874 &ndas...
# }
# en.wikipedia.org (parse) Resource slack
# Quora (en) data
# {
#   infobox: <dict(20)> name, logo, collapsible, collapsetext, scree...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:Q...
#   pageid: 26749224
#   parsetree: <str(73307)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: Quora
#   wikibase: Q51711
#   wikidata_url: https://www.wikidata.org/wiki/Q51711
#   wikitext: <str(55939)> {{Short description|Question-and-answer p...
# }
# en.wikipedia.org (query) Fujitsu
# Resource slack (en) data
# {
#   pageid: 42417759
#   parsetree: <str(8135)> <root>'''Resource slack''', in the [[busi...
#   requests: <list(1)> parse
#   title: Resource slack
#   wikibase: Q17078173
#   wikidata_url: https://www.wikidata.org/wiki/Q17078173
#   wikitext: <str(6914)> '''Resource slack''', in the [[business]] ...
# }
# en.wikipedia.org (parse) SLAC (disambiguation)
# en.wikipedia.org (query) Fujitsu (&plcontinue=58222|0|Pulsar_(watch))
# SLAC (disambiguation) (en) data
# {
#   pageid: 2538824
#   parsetree: <str(556)> <root>'''SLAC''' can mean* [[SL Agritech C...
#   requests: <list(1)> parse
#   title: SLAC (disambiguation)
#   wikibase: Q7390726
#   wikidata_url: https://www.wikidata.org/wiki/Q7390726
#   wikitext: <str(469)> '''SLAC''' can mean* [[SL Agritech Corporat...
# }
# en.wikipedia.org (imageinfo) File:Surgery - Nationwide.jpgen.wikipedia.org (parse) Shanon Slack
# [2022-01-20 10:07:37-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[0]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:37-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[13]': Starting task run...
# www.wikidata.org (labels) P452|P4742|P989|P1482|P31|P646|Q62|P227...
# Nationwide (album) (en) data
# {
#   image: <list(1)> {'kind': 'parse-cover', 'file': 'File:Surgery -...
#   infobox: <dict(14)> name, type, artist, cover, released, recorde...
#   pageid: 38891895
#   parsetree: <str(5571)> <root><template><title>Infobox album</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Nationwide (album)
#   wikibase: Q17061918
#   wikidata_url: https://www.wikidata.org/wiki/Q17061918
#   wikitext: <str(2450)> {{Infobox album| name       = Nationwide| ...
# }
# en.wikipedia.org (parse) 58222
# Shanon Slack (en) data
# {
#   infobox: <dict(20)> name, other_names, image_size, birth_date, b...
#   pageid: 40317678
#   parsetree: <str(16103)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Shanon Slack
#   wikibase: Q15987725
#   wikidata_url: https://www.wikidata.org/wiki/Q15987725
#   wikitext: <str(9573)> {{short description|American mixed martial...
# }
# en.wikipedia.org (query) Novartis
# en.wikipedia.org (parse) Slack (project management)
# Float (project management) (en) data
# {
#   pageid: 401024
#   parsetree: <str(4333)> <root><template><title>More footnotes</ti...
#   requests: <list(1)> parse
#   title: Float (project management)
#   wikibase: Q185958
#   wikidata_url: https://www.wikidata.org/wiki/Q185958
#   wikitext: <str(3609)> {{More footnotes|date=December 2007}}In [[...
# }
# en.wikipedia.org (parse) Slack (river)
# www.wikidata.org (wikidata) Q186394
# en.wikipedia.org (parse) 159284
# en.wikipedia.org (imageinfo) File:PSslack6574.jpg
# www.wikidata.org (labels) Q29123072|Q3011384|Q25245117|P3362|P856...
# Slack (river) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:PSslack65...
#   infobox: <dict(9)> name, image, image_caption, source1_location,...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 14862416
#   parsetree: <str(4218)> <root><template><title>Expand French</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Slack (river)
#   wikibase: Q476585
#   wikidata_url: https://www.wikidata.org/wiki/Q476585
#   wikitext: <str(1530)> {{Expand French|Slack (fleuve)|date=Januar...
# }
# en.wikipedia.org (parse) Slack (software)
# en.wikipedia.org (restbase) /page/summary/Twitter
# www.wikidata.org (wikidata) Q507154
# en.wikipedia.org (imageinfo) File:FavBlogs - Flickr - USDAgov.jpg...
# [2022-01-20 10:07:38-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[10]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:38-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[14]': Starting task run...
# Slack (software) (en) data
# {
#   infobox: <dict(14)> name, title, logo, author, developer, releas...
#   pageid: 41202764
#   parsetree: <str(47578)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: Slack (software)
#   wikibase: Q17130715
#   wikidata_url: https://www.wikidata.org/wiki/Q17130715
#   wikitext: <str(39910)> {{Short description|Messaging software ap...
# }
# www.wikidata.org (labels) P3362|P856|P2002|P910|P268|P154|Q116679...
# en.wikipedia.org (query) Siemens
# www.wikidata.org (labels) Q1815128|P1448|P8687|Q5507497|P6298|P11...
# en.wikipedia.org (parse) 168632
# www.wikidata.org (labels) P2226|Q3552585|P2013|Q30338508|P166|P67...
# Twitter (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> twttr, twitter.com
#   assessments: <dict(10)> California, Companies, Brands, Internet ...
# en.wikipedia.org (restbase) /page/summary/Fujitsu  claims: <dict(110)> P277, P31, P373, P856, P910, P137, P227, P24...
# www.wikidata.org (wikidata) Q81230
#
#   description: American social networking service
#   exhtml: <str(770)> <p><b>Twitter</b> is an American microbloggin...
#   exrest: <str(756)> Twitter is an American microblogging and soci...
#   extext: <str(1268)> **Twitter** is an American microblogging and...
#   extract: <str(1356)> <p class="mw-empty-elt"></p><p class="mw-em...
#   image: <list(13)> {'kind': 'query-pageimage', 'file': 'File:NASA...
#   infobox: <dict(30)> name, logo, logo_size, screenshot, caption, ...
#   iwlinks: <list(9)> https://commons.wikimedia.org/wiki/Category:T...
#   label: Twitter
#   labels: <dict(142)> Q41689563, P8313, P1792, P6760, P7827, P856,...
#   length: 343,448
#   links: <list(1051)> 2009 student protests in Austria, 2010 FIFA ...
#   modified: <dict(2)> page, wikidata
#   pageid: 9988187
#   parsetree: <str(414233)> <root><template><title>Short descriptio...
#   random: Leonie Huddy
#   redirects: <list(73)> {'pageid': 10238728, 'ns': 0, 'title': 'Tw...
#   requests: <list(10)> query, query, query, parse, wikidata, label...
#   title: Twitter
#   url: https://en.wikipedia.org/wiki/Twitter
#   url_raw: https://en.wikipedia.org/wiki/Twitter?action=raw
#   watchers: 1,486
#   what: social networking service
#   wikibase: Q918
#   wikidata: <dict(110)> programming language (P277), instance of (...
#   wikidata_pageid: 1241
#   wikidata_url: https://www.wikidata.org/wiki/Q918
#   wikitext: <str(342238)> {{Short description|American social netw...
# }
# en.wikipedia.org (parse) Twitter
# en.wikipedia.org (imageinfo) File:Shiodome City Center 2012.JPG
# Fujitsu (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> Fujitsu Ltd., Fujitsu Limited, Fujitsū Kabush...
#   assessments: <dict(5)> Japan, Companies, Computing, Telecommunic...
#   claims: <dict(54)> P373, P31, P910, P856, P159, P646, P1454, P57...
#   description: <str(76)> Japanese multinational information techno...
#   exhtml: <str(801)> <p><b>Fujitsu Limited</b><span style="font-we...
#   exrest: <str(747)> Fujitsu Limited  is a Japanese multinational ...
#   extext: <str(1020)> **Fujitsu Limited** (富士通株式会社, _Fujitsū Kabus...
#   extract: <str(1226)> <p class="mw-empty-elt"></p><p><b>Fujitsu L...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:Shiod...
#   infobox: <dict(24)> name, native_name, native_name_lang, romaniz...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:F...
#   label: Fujitsu
#   labels: <dict(97)> Q29123072, Q3011384, Q25245117, P3362, P856, ...
#   length: 49,999
#   links: <list(693)> 5G, AEON (company), AGC Inc., AMD, AOR (compa...
#   modified: <dict(2)> page, wikidata
#   pageid: 58222
#   parsetree: <str(62460)> <root><template><title>short description...
#   random: Henry Scheidemann
#   redirects: <list(50)> {'pageid': 578687, 'ns': 0, 'title': 'Fuji...
#   requests: <list(8)> query, query, parse, wikidata, labels, label...
#   title: Fujitsu
#   url: https://en.wikipedia.org/wiki/Fujitsu
#   url_raw: https://en.wikipedia.org/wiki/Fujitsu?action=raw
#   watchers: 144
#   what: business
#   wikibase: Q186394
#   wikidata: <dict(53)> Commons category (P373), instance of (P31),...
#   wikidata_pageid: 185170
#   wikidata_url: https://www.wikidata.org/wiki/Q186394
#   wikitext: <str(49613)> {{short description|Japanese multinationa...
# }
# en.wikipedia.org (parse) Fujitsu
# www.wikidata.org (labels) Q7510906|Q107156523|Q1440421|P3362|P240...
# [2022-01-20 10:07:39-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[1]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:39-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[15]': Starting task run...
# Twitter (en) data
# {
#   infobox: <dict(30)> name, logo, logo_size, screenshot, caption, ...
#   iwlinks: <list(9)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 9988187
#   parsetree: <str(414233)> <root><template><title>Short descriptio...
#   requests: <list(1)> parse
#   title: Twitter
#   wikibase: Q918
#   wikidata_url: https://www.wikidata.org/wiki/Q918
#   wikitext: <str(342238)> {{Short description|American social netw...
# }
# en.wikipedia.org (query) Zillow
# en.wikipedia.org (imageinfo) File:Shiodome City Center 2012.JPG
# www.wikidata.org (labels) Q29123421|P373|Q29123426|Q4830453|P3347...
# [2022-01-20 10:07:40-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[12]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:40-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[16]': Starting task run...
# Fujitsu (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Shiodome ...
#   infobox: <dict(24)> name, native_name, native_name_lang, romaniz...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:F...
#   pageid: 58222
#   parsetree: <str(62460)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Fujitsu
#   wikibase: Q186394
#   wikidata_url: https://www.wikidata.org/wiki/Q186394
#   wikitext: <str(49613)> {{short description|Japanese multinationa...
# }
# en.wikipedia.org (parse) 4035097
# www.wikidata.org (labels) P2003|P2427|P1365|Q7389502|Q17353641|Q1...
# en.wikipedia.org (query) Basecamp
# en.wikipedia.org (restbase) /page/summary/Novartis
# www.wikidata.org (wikidata) Q8071921
# en.wikipedia.org (imageinfo) File:Novartis K25 Basel.jpg|File:Ind...
# en.wikipedia.org (parse) 20341
# www.wikidata.org (labels) P2003|P31|P2427|P646|Q82059|P1454|P3242...Novartis (en) data
#
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Novartis International AG
#   assessments: <dict(3)> Switzerland, Companies, Pharmacology
#   claims: <dict(65)> P452, P373, P856, P910, P646, P159, P18, P31,...
#   description: Swiss multinational pharmaceutical corporation
#   exhtml: <str(184)> <p><b>Novartis International AG</b> is a Swis...
#   exrest: <str(170)> Novartis International AG is a Swiss multinat...
#   extext: <str(1444)> **Novartis International AG** is a Swiss mul...
#   extract: <str(1511)> <p><span></span></p><p><b>Novartis Internat...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:Novar...
#   infobox: <dict(24)> name, logo, logo_size, image, image_size, im...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:N...
#   label: Novartis
#   labels: <dict(106)> P3362, P856, P2002, P910, P268, P154, Q11667...
#   length: 130,920
#   links: <list(443)> A2A receptor, ABB, ADHD, AVXS-101, Access to ...
#   modified: <dict(2)> page, wikidata
#   pageid: 159284
#   parsetree: <str(154160)> <root><template><title>short descriptio...
#   random: Moccasin Springs Formation
#   redirects: <list(44)> {'pageid': 590056, 'ns': 0, 'title': 'Sand...
#   requests: <list(8)> query, parse, wikidata, labels, labels, labe...
#   title: Novartis
#   url: https://en.wikipedia.org/wiki/Novartis
#   url_raw: https://en.wikipedia.org/wiki/Novartis?action=raw
#   watchers: 206
#   what: business
#   wikibase: Q507154
#   wikidata: <dict(64)> industry (P452), Commons category (P373), o...
#   wikidata_pageid: 476852
#   wikidata_url: https://www.wikidata.org/wiki/Q507154
#   wikitext: <str(130211)> {{short description|Swiss multinational ...
# }
# en.wikipedia.org (parse) Novartis
# www.wikidata.org (labels) Q1786253|Q778575|Q7510892|P361|Q3033872...
# www.wikidata.org (wikidata) Q36908
# en.wikipedia.org (imageinfo) File:Novartis K25 Basel.jpg
# [2022-01-20 10:07:41-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[13]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:41-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[17]': Starting task run...
# www.wikidata.org (labels) P7033|Q820236|P646|P227|P3964|P2924|Q81...
# Novartis (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Novartis ...
#   infobox: <dict(24)> name, logo, logo_size, image, image_size, im...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:N...
#   pageid: 159284
#   parsetree: <str(154160)> <root><template><title>short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Novartis
#   wikibase: Q507154
#   wikidata_url: https://www.wikidata.org/wiki/Q507154
#   wikitext: <str(130211)> {{short description|Swiss multinational ...
# }
# en.wikipedia.org (query) Atlassian
# en.wikipedia.org (restbase) /page/summary/Zillow
# Zillow (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(4)> United States, Companies, Websites, Home ...
#   claims: <dict(25)> P856, P414, P31, P159, P17, P169, P571, P1454...
#   description: American real estate website
#   exhtml: <str(441)> <p><b>Zillow Group, Inc.</b>, or simply <b>Zi...
#   exrest: <str(420)> Zillow Group, Inc., or simply Zillow, is an A...
#   extext: <str(466)> **Zillow Group, Inc.** , or simply **Zillow**...
#   extract: <str(489)> <p><b>Zillow Group, Inc.</b>, or simply <b>Z...
#   infobox: <dict(17)> name, logo, logo_size, type, traded_as, foun...
#   label: Zillow
#   labels: <dict(35)> P2003, P31, P2427, P646, Q82059, P1454, P3242...
#   length: 33,083
#   links: <list(167)> 99Acres.com, ACH Network, AOL, Adzuna, Americ...
#   modified: <dict(2)> page, wikidata
#   pageid: 4035097
#   parsetree: <str(42280)> <root><template><title>short description...
#   random: R29/R99 (New York City Subway car)
#   redirects: <list(9)> {'pageid': 18580524, 'ns': 0, 'title': 'Zes...
#   requests: <list(5)> query, parse, wikidata, labels, restbase
#   title: Zillow
#   url: https://en.wikipedia.org/wiki/Zillow
#   url_raw: https://en.wikipedia.org/wiki/Zillow?action=raw
#   watchers: 108
#   what: business
#   wikibase: Q8071921
#   wikidata: <dict(25)> official website (P856), stock exchange (P4...
#   wikidata_pageid: 8021310
#   wikidata_url: https://www.wikidata.org/wiki/Q8071921
#   wikitext: <str(32917)> {{short description|American real estate ...
# }
# en.wikipedia.org (parse) Zillow
# en.wikipedia.org (parse) 26569739
# www.wikidata.org (labels) P3987|Q310481|Q7510880|P31|Q101333|P646...
# [2022-01-20 10:07:41-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[15]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:41-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[18]': Starting task run...
# www.wikidata.org (labels) P8785|P156|P5429|P7388|Q22857
# Zillow (en) data
# {
#   infobox: <dict(17)> name, logo, logo_size, type, traded_as, foun...
#   pageid: 4035097
#   parsetree: <str(42280)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Zillow
#   wikibase: Q8071921
#   wikidata_url: https://www.wikidata.org/wiki/Q8071921
#   wikitext: <str(32917)> {{short description|American real estate ...
# }
# www.wikidata.org (wikidata) Q757307
# en.wikipedia.org (query) REI
# Note: Wikidata item Q36908 missing 'instance of' (P31)
# en.wikipedia.org (restbase) /page/summary/Mountaineering
# en.wikipedia.org (parse) 548273
# www.wikidata.org (labels) P31|P2427|P646|Q62|Q82059|P3553|P1454|P...
# en.wikipedia.org (imageinfo) File:Summitting Island Peak.jpg|File...
# en.wikipedia.org (restbase) /page/summary/Siemens
# Mountaineering (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(2)> mountain climbing, alpinism
#   assessments: <dict(3)> Mountains, Climbing, Backpacking
#   claims: <dict(45)> P508, P373, P279, P910, P349, P227, P646, P18...
#   description: Sport of mountain climbing
#   exhtml: <str(340)> <p> <br /><b>Mountaineering</b>, or <b>alpini...
#   exrest: <str(312)> Mountaineering, or alpinism, is the set of ou...
#   extext: <str(795)> **Mountaineering** , or **alpinism** , is the...
#   extract: <str(855)> <p class="mw-empty-elt"></p><p><br><b>Mounta...
#   image: <list(5)> {'kind': 'query-pageimage', 'file': 'File:M Rai...
#   infobox: <dict(2)> boxes, count
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   label: mountaineering
#   labels: <dict(55)> P7033, Q820236, P646, P227, P3964, P2924, Q81...
#   length: 44,080
#   links: <list(424)> 1905 Kanchenjunga expedition, 1922 British Mo...
#   modified: <dict(2)> page, wikidata
#   pageid: 20341
#   parsetree: <str(55227)> <root><template><title>short description...
#   random: Thermo-magnetic motor
#   redirected: <list(1)> {'from': 'Basecamp', 'to': 'Mountaineering...
#   redirects: <list(17)> {'pageid': 48546, 'ns': 0, 'title': 'Mount...
#   requests: <list(7)> query, parse, wikidata, labels, labels, rest...
#   title: Mountaineering
#   url: https://en.wikipedia.org/wiki/Mountaineering
#   url_raw: https://en.wikipedia.org/wiki/Mountaineering?action=raw
#   watchers: 240
#   wikibase: Q36908
#   wikidata: <dict(45)> BNCF Thesaurus ID (P508), Commons category ...
#   wikidata_pageid: 39513
#   wikidata_url: https://www.wikidata.org/wiki/Q36908
#   wikitext: <str(43788)> {{short description|Sport of mountain cli...
# }
# en.wikipedia.org (parse) Basecamp
# www.wikidata.org (wikidata) Q3414933
# en.wikipedia.org (imageinfo) File:The Wings created by Studio Lib...
# [2022-01-20 10:07:42-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[16]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:42-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[19]': Starting task run...
# www.wikidata.org (labels) P2003|P31|P646|P2847|P1454|P856|P2002|P...
# Siemens (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(5)> Siemens bestaat in Nederland sinds 1879, Siem...
#   assessments: <dict(5)> Germany, Energy, Companies, Brands, Trains
#   claims: <dict(94)> P214, P373, P31, P154, P112, P856, P910, P646...
#   description: German multinational conglomerate company
#   exhtml: <str(186)> <p><b>Siemens AG</b> is a German multinationa...
#   exrest: <str(172)> Siemens AG is a German multinational conglome...
#   extext: <str(897)> **Siemens AG** (German pronunciation: [ˈziːmə...
#   extract: <str(1181)> <p class="mw-empty-elt"></p><p><b>Siemens A...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:The W...
#   infobox: <dict(24)> name, logo, image, image_caption, type, trad...
#   iwlinks: <list(10)> https://commons.wikimedia.org/wiki/Category:...
#   label: Siemens
#   labels: <dict(193)> Q7510906, Q107156523, Q1440421, P3362, P2403...
#   length: 104,820
#   links: <list(425)> 2004 Summer Olympic Games, 2009 Iranian elect...
#   modified: <dict(2)> page, wikidata
#   pageid: 168632
#   parsetree: <str(125510)> <root><template><title>short descriptio...
#   random: Antoinette Burton
#   redirects: <list(33)> {'pageid': 1189207, 'ns': 0, 'title': 'Sie...
#   requests: <list(9)> query, parse, wikidata, labels, labels, labe...
#   title: Siemens
#   url: https://en.wikipedia.org/wiki/Siemens
#   url_raw: https://en.wikipedia.org/wiki/Siemens?action=raw
#   watchers: 343
#   what: business
#   wikibase: Q81230
#   wikidata: <dict(93)> VIAF ID (P214), Commons category (P373), in...
#   wikidata_pageid: 83699
#   wikidata_url: https://www.wikidata.org/wiki/Q81230
#   wikitext: <str(104044)> {{short description|German multinational...
# }
# en.wikipedia.org (parse) Siemens
# Mountaineering (en) data
# {
#   infobox: <dict(2)> boxes, count
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 20341
#   parsetree: <str(55227)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: Mountaineering
#   wikibase: Q36908
#   wikidata_url: https://www.wikidata.org/wiki/Q36908
#   wikitext: <str(43788)> {{short description|Sport of mountain cli...
# }
# en.wikipedia.org (query) Hubspot
# en.wikipedia.org (parse) 22479089
# en.wikipedia.org (imageinfo) File:The Wings created by Studio Lib...
# [2022-01-20 10:07:42-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[14]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:42-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[2]': Starting task run...
# Siemens (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:The Wings...
#   infobox: <dict(24)> name, logo, image, image_caption, type, trad...
#   iwlinks: <list(10)> https://commons.wikimedia.org/wiki/Category:...
#   pageid: 168632
#   parsetree: <str(125510)> <root><template><title>short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Siemens
#   wikibase: Q81230
#   wikidata_url: https://www.wikidata.org/wiki/Q81230
#   wikitext: <str(104044)> {{short description|German multinational...
# }
# en.wikipedia.org (query) Square
# www.wikidata.org (wikidata) Q5926631
# www.wikidata.org (labels) P740|P3347|P112|Q6832945|P452|P463|Q679...
# www.wikidata.org (labels) P2003|P31|P646|P3553|Q13677|P1454|P856|...en.wikipedia.org (restbase) /page/summary/REI
#
# en.wikipedia.org (parse) 659939
# REI (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> R.E.I., REI, Recreational Equipment
#   assessments: <dict(5)> United States, Companies, Cooperatives, B...
#   claims: <dict(26)> P31, P856, P17, P159, P373, P571, P1454, P200...
#   description: American consumer cooperative
#   exhtml: <str(330)> <p><b>Recreational Equipment, Inc.</b>, commo...
#   exrest: <str(309)> Recreational Equipment, Inc., commonly known ...
#   extext: <str(475)> **Recreational Equipment, Inc.** , commonly k...
#   extract: <str(498)> <p><b>Recreational Equipment, Inc.</b>, comm...
#   image: <list(2)> {'kind': 'restbase-original', 'width': 157, 'he...
#   infobox: <dict(16)> name, logo, logo_size, type, key_people, ind...
#   label: Recreational Equipment, Inc.
#   labels: <dict(32)> P2003, P31, P646, P2847, P1454, P856, P2002, ...
#   length: 26,401
#   links: <list(103)> 2018 NRA boycott, Academy Sports + Outdoors, ...
#   modified: <dict(2)> page, wikidata
#   pageid: 548273
#   parsetree: <str(31754)> <root><template><title>short description...
#   random: Cyrtodactylus dattkyaikensis
#   redirects: <list(11)> {'pageid': 6231338, 'ns': 0, 'title': 'Rec...
#   requests: <list(5)> query, parse, wikidata, labels, restbase
#   title: REI
#   url: https://en.wikipedia.org/wiki/REI
#   url_raw: https://en.wikipedia.org/wiki/REI?action=raw
#   watchers: 82
#   what: consumer cooperative
#   wikibase: Q3414933
#   wikidata: <dict(26)> instance of (P31), official website (P856),...
#   wikidata_pageid: 3253736
#   wikidata_url: https://www.wikidata.org/wiki/Q3414933
#   wikitext: <str(26260)> {{short description|American consumer coo...
# }
# en.wikipedia.org (parse) REI
# en.wikipedia.org (restbase) /page/summary/Atlassian
# www.wikidata.org (wikidata) Q164
# Atlassian (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Atlassian Bamboo
#   assessments: <dict(2)> Software, Companies
#   claims: <dict(39)> P31, P646, P856, P17, P571, P740, P159, P154,...
#   description: Australian enterprise software company
#   exhtml: <str(176)> <p><b>Atlassian Corporation Plc</b> is an Aus...
#   exrest: <str(162)> Atlassian Corporation Plc is an Australian so...
#   extext: <str(167)> **Atlassian Corporation Plc** () is an Austra...
#   extract: <str(220)> <p class="mw-empty-elt"></p><p><b>Atlassian ...
#   infobox: <dict(15)> name, logo, type, traded_as, industry, found...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   label: Atlassian
#   labels: <dict(62)> P31, P2427, P646, Q62, Q82059, P3553, P1454, ...
#   length: 26,465
#   links: <list(156)> ADP (company), ASML Holding, Accel Partners, ...
#   modified: <dict(2)> page, wikidata
#   pageid: 26569739
#   parsetree: <str(33474)> <root><template><title>Cleanup</title><p...
#   random: Juan Ríos
#   redirects: <list(11)> {'pageid': 11829102, 'ns': 0, 'title': 'At...
#   requests: <list(6)> query, parse, wikidata, labels, labels, restbase
#   title: Atlassian
#   url: https://en.wikipedia.org/wiki/Atlassian
#   url_raw: https://en.wikipedia.org/wiki/Atlassian?action=raw
#   watchers: 128
#   what: business
#   wikibase: Q757307
#   wikidata: <dict(39)> instance of (P31), Freebase ID (P646), offi...
#   wikidata_pageid: 712301
#   wikidata_url: https://www.wikidata.org/wiki/Q757307
#   wikitext: <str(26330)> {{Cleanup|date=August 2020|reason= Diffic...
# }
# en.wikipedia.org (parse) Atlassian
# REI (en) data
# {
#   infobox: <dict(16)> name, logo, logo_size, type, key_people, ind...
#   pageid: 548273
#   parsetree: <str(31754)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: REI
#   wikibase: Q3414933
#   wikidata_url: https://www.wikidata.org/wiki/Q3414933
#   wikitext: <str(26260)> {{short description|American consumer coo...
# }
# [2022-01-20 10:07:43-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[18]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:43-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[20]': Starting task run...
# [2022-01-20 10:07:43-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[17]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:43-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[21]': Starting task run...
# en.wikipedia.org (query) Schroders
# www.wikidata.org (labels) P2959|P7033|P31|Q815741|Q7333618|P646|P...
# Atlassian (en) data
# {
#   infobox: <dict(15)> name, logo, type, traded_as, industry, found...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 26569739
#   parsetree: <str(33474)> <root><template><title>Cleanup</title><p...
#   requests: <list(1)> parse
#   title: Atlassian
#   wikibase: Q757307
#   wikidata_url: https://www.wikidata.org/wiki/Q757307
#   wikitext: <str(26330)> {{Cleanup|date=August 2020|reason= Diffic...
# }
# en.wikipedia.org (query) Gett
# en.wikipedia.org (parse) 1919438
# en.wikipedia.org (restbase) /page/summary/HubSpot
# HubSpot (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> HubSpot Inc
#   assessments: <dict(3)> United States, Companies, Marketing & Adv...
#   claims: <dict(26)> P373, P31, P856, P159, P571, P1454, P154, P34...
#   description: American marketing software company
#   exhtml: <str(197)> <p><b>HubSpot</b> is an American developer an...
#   exrest: <str(183)> HubSpot is an American developer and marketer...
#   extext: <str(404)> **HubSpot** is an American developer and mark...
#   extract: <str(425)> <p><b>HubSpot</b> is an American developer a...
#   infobox: <dict(16)> name, logo, type, traded_as, founders, key_p...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:H...
#   label: HubSpot
#   labels: <dict(34)> P2003, P31, P646, P3553, Q13677, P1454, P856,...
#   length: 22,901
#   links: <list(74)> Alexa Internet, Artificial intelligence, Asset...
#   modified: <dict(2)> page, wikidata
#   pageid: 22479089
#   parsetree: <str(30932)> <root><template><title>short description...
#   random: Don Featherstone (filmmaker, 1902–1984)
#   redirected: <list(1)> {'from': 'Hubspot', 'to': 'HubSpot'}
#   redirects: <list(4)> {'pageid': 22479105, 'ns': 0, 'title': 'Hub...
#   requests: <list(5)> query, parse, wikidata, labels, restbase
#   title: HubSpot
#   url: https://en.wikipedia.org/wiki/HubSpot
#   url_raw: https://en.wikipedia.org/wiki/HubSpot?action=raw
#   watchers: 76
#   what: business
#   wikibase: Q5926631
#   wikidata: <dict(26)> Commons category (P373), instance of (P31),...
#   wikidata_pageid: 5698746
#   wikidata_url: https://www.wikidata.org/wiki/Q5926631
#   wikitext: <str(22691)> {{short description|American marketing so...
# }
# en.wikipedia.org (parse) Hubspot
# [2022-01-20 10:07:44-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[19]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:44-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[22]': Starting task run...
# en.wikipedia.org (parse) 36323895
# www.wikidata.org (wikidata) Q1142797
# HubSpot (en) data
# {
#   infobox: <dict(16)> name, logo, type, traded_as, founders, key_p...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:H...
#   pageid: 22479089
#   parsetree: <str(30932)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: HubSpot
#   wikibase: Q5926631
#   wikidata_url: https://www.wikidata.org/wiki/Q5926631
#   wikitext: <str(22691)> {{short description|American marketing so...
# }
# en.wikipedia.org (query) Linklaters
# www.wikidata.org (labels) P31|P646|P227|Q5225895|P361|P1454|P3642...
# www.wikidata.org (labels) P279|Q209|P2812|P508|Q268132|P1036|P134...
# www.wikidata.org (wikidata) Q5553771
# en.wikipedia.org (parse) 809606
# www.wikidata.org (labels) P577|P31|P856|Q620615|P306|P571|Q109792...
# en.wikipedia.org (restbase) /page/summary/Square
# en.wikipedia.org (imageinfo) File:SquareDefinition.svg|File:Regul...
# www.wikidata.org (wikidata) Q1317942
# www.wikidata.org (labels) P31|P646|P361|P1454|P856|P2002|P154|P57...
# Square (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(5)> 2-orthoplex, bicross, 2-cube, 2-cross-polytop...
#   assessments: <dict(2)> Wikipedia 1.0, Mathematics
#   claims: <dict(35)> P487, P279, P373, P227, P646, P1036, P1322, P...
#   description: Regular quadrilateral
#   exhtml: <str(555)> <p>In Euclidean geometry, a <b>square</b> is ...
#   exrest: <str(260)> In Euclidean geometry, a square is a regular ...
#   extext: <str(346)> In Euclidean geometry, a **square** is a regu...
#   extract: <str(735)> <p class="mw-empty-elt"></p><p>In Euclidean ...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:Regul...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   label: square
#   labels: <dict(62)> P2959, P7033, P31, Q815741, Q7333618, P646, P...
#   length: 17,453
#   links: <list(247)> 1 22 polytope, 1 32 polytope, 1 42 polytope, ...
#   modified: <dict(2)> page, wikidata
#   pageid: 659939
#   parsetree: <str(22403)> <root><template><title>Short description...
#   random: Emir Sultan Mosque
#   redirects: <list(30)> {'pageid': 660425, 'ns': 0, 'title': 'Squa...
#   requests: <list(7)> query, parse, wikidata, labels, labels, rest...
#   title: Square
#   url: https://en.wikipedia.org/wiki/Square
#   url_raw: https://en.wikipedia.org/wiki/Square?action=raw
#   watchers: 197
#   what: geometric shape
#   wikibase: Q164
#   wikidata: <dict(34)> Unicode character (P487), subclass of (P279...
#   wikidata_pageid: 300
#   wikidata_url: https://www.wikidata.org/wiki/Q164
#   wikitext: <str(17226)> {{Short description|Regular quadrilateral...
# }
# en.wikipedia.org (parse) Square
# en.wikipedia.org (restbase) /page/summary/Schroders
# [2022-01-20 10:07:45-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[2]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:45-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[23]': Starting task run...
# Square (en) data
# {
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 659939
#   parsetree: <str(22403)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: Square
#   wikibase: Q164
#   wikidata_url: https://www.wikidata.org/wiki/Q164
#   wikitext: <str(17226)> {{Short description|Regular quadrilateral...
# }
# en.wikipedia.org (imageinfo) File:Site of Loriners Hall - 1 Londo...
# en.wikipedia.org (query) JPMorgan Chase
# en.wikipedia.org (restbase) /page/summary/Gett
# en.wikipedia.org (imageinfo) File:HaBarzel street in Tel-Aviv.jpg
# Schroders (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> Schroders plc
#   assessments: <dict(4)> Companies, London, Organizations, Finance...
#   claims: <dict(34)> P31, P646, P227, P1320, P214, P414, P159, P24...
#   description: British asset management company
#   exhtml: <str(342)> <p><b>Schroders plc</b> is a British multinat...
#   exrest: <str(328)> Schroders plc is a British multinational asse...
#   extext: <str(588)> **Schroders plc** is a British multinational ...
#   extract: <str(612)> <p><b>Schroders plc</b> is a British multina...
#   image: <list(6)> {'kind': 'query-pageimage', 'file': 'File:Site ...
#   infobox: <dict(17)> name, logo, image, image_size, image_caption...
#   label: Schroders
#   labels: <dict(46)> P31, P646, P227, Q5225895, P361, P1454, P3642...
#   length: 8,370
#   links: <list(263)> 3i, AMP Capital, APG (pension fund), Abrdn, A...
#   modified: <dict(2)> page, wikidata
#   pageid: 1919438
#   parsetree: <str(12691)> <root><template><title>short description...
#   random: Divna Veković
#   redirects: <list(9)> {'pageid': 1919440, 'ns': 0, 'title': 'Schr...
#   requests: <list(6)> query, parse, wikidata, labels, restbase, im...
#   title: Schroders
#   url: https://en.wikipedia.org/wiki/Schroders
#   url_raw: https://en.wikipedia.org/wiki/Schroders?action=raw
#   watchers: 41
#   what: business
#   wikibase: Q1142797
#   wikidata: <dict(34)> instance of (P31), Freebase ID (P646), GND ...
#   wikidata_pageid: 1089459
#   wikidata_url: https://www.wikidata.org/wiki/Q1142797
#   wikitext: <str(8227)> {{short description|British asset manageme...
# }
# en.wikipedia.org (parse) Schroders
# en.wikipedia.org (query) JPMorgan Chase (&plcontinue=231001|0|Mat...
# Gett (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> GetTaxi
#   assessments: <dict(4)> Companies, Israel, Transport, Apps
#   claims: <dict(17)> P31, P571, P856, P275, P452, P407, P577, P306...
#   description: <str(90)> On-demand mobility company that connects ...
#   exhtml: <str(167)> <p><b>Gett</b>, previously known as <b>GetTax...
#   exrest: <str(146)> Gett, previously known as GetTaxi, is an Isra...
#   extext: <str(1016)> **Gett** , previously known as **GetTaxi** ,...
#   extract: <str(1152)> <link rel="mw-deduplicated-inline-style" hr...
#   image: <list(4)> {'kind': 'query-pageimage', 'file': 'File:HaBar...
#   infobox: <dict(15)> name, logo, former_name, type, industry, fou...
#   label: Gett
#   labels: <dict(34)> P577, P31, P856, Q620615, P306, P571, Q109792...
#   length: 9,853
#   links: <list(136)> 2021 Gorillas strikes, 99 (app), Access Indus...
#   modified: <dict(2)> page, wikidata
#   pageid: 36323895
#   parsetree: <str(13665)> <root><template><title>distinguish</titl...
#   random: All Mornin' Long
#   redirects: <list(1)> {'pageid': 50657067, 'ns': 0, 'title': 'Get...
#   requests: <list(6)> query, parse, wikidata, labels, restbase, im...
#   title: Gett
#   url: https://en.wikipedia.org/wiki/Gett
#   url_raw: https://en.wikipedia.org/wiki/Gett?action=raw
#   what: business
#   wikibase: Q5553771
#   wikidata: <dict(17)> instance of (P31), inception (P571), offici...
#   wikidata_pageid: 5313992
#   wikidata_url: https://www.wikidata.org/wiki/Q5553771
#   wikitext: <str(9751)> {{distinguish|Getir|Gettr}}{{short descrip...
# }
# en.wikipedia.org (parse) Gett
# en.wikipedia.org (restbase) /page/summary/Linklaters
# [2022-01-20 10:07:45-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[21]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:07:45-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[20]': Finished task run for task with final state: 'Success'
# en.wikipedia.org (imageinfo) File:Site of Loriners Hall - 1 Londo...
# Linklaters (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(1)> magic circle law firm
#   assessments: <dict(3)> Law, Business, London
#   claims: <dict(17)> P646, P159, P154, P856, P571, P31, P1454, P26...
#   exhtml: <str(251)> <p><b>Linklaters LLP</b> is a multinational l...
#   exrest: <str(237)> Linklaters LLP is a multinational law firm he...
#   extext: <str(832)> **Linklaters LLP** is a multinational law fir...
#   extract: <str(890)> <p class="mw-empty-elt"></p><p><b>Linklaters...
#   infobox: <dict(12)> name, logo, headquarters, num_offices, num_l...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:L...
#   label: Linklaters
# ...
# }
# en.wikipedia.org (query) Hitachi
# www.wikidata.org (labels) P1329|P2013|P3743|Q4830453|P112|P3347|Q...
# Robert Muchamore (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robert Mu...
#   infobox: <dict(11)> image, imagesize, name, caption, birth_name,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 1803013
#   parsetree: <str(18675)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Robert Muchamore
#   wikibase: Q1243319
#   wikidata_url: https://www.wikidata.org/wiki/Q1243319
#   wikitext: <str(14402)> {{Use dmy dates|date=January 2021}}{{Use ...
# }
# en.wikipedia.org (parse) Robin Hood
# en.wikipedia.org (query) Hitachi (&plcontinue=188676|0|Nichia)
# en.wikipedia.org (restbase) /page/summary/VMware
# en.wikipedia.org (imageinfo) File:Robin-hood-and-maid-marion-01.png
# en.wikipedia.org (parse) 188676
# en.wikipedia.org (imageinfo) File:VMware HQ campus 3401 Hillview ...
# Robin Hood (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin-hoo...
#   infobox: <dict(15)> colour, name, series, image, caption, first,...
#   iwlinks: <list(7)> https://commons.wikimedia.org/wiki/category:R...
#   pageid: 26171
#   parsetree: <str(142773)> <root><template><title>Short descriptio...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood
#   wikibase: Q122634
#   wikidata_url: https://www.wikidata.org/wiki/Q122634
#   wikitext: <str(108546)> {{Short description|Heroic outlaw in Eng...
# }
# en.wikipedia.org (parse) Robin Hood (1912 film)
# VMware (en) data
# en.wikipedia.org (imageinfo) File:Robin Hood-1912 lowres-scene.jpg
# www.wikidata.org (wikidata) Q53238
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> VMware, Inc., VMware, vmware.com
#   assessments: <dict(2)> Companies, Computing
#   claims: <dict(48)> P373, P31, P856, P910, P646, P1482, P414, P94...
#   description: Multi-cloud service provider for all apps
#   exhtml: <str(217)> <p><b>VMware, Inc.</b> is an American cloud c...
#   exrest: <str(203)> VMware, Inc. is an American cloud computing a...
#   extext: <str(465)> **VMware, Inc.** is an American cloud computi...
#   extract: <str(570)> <link rel="mw-deduplicated-inline-style" hre...
#   image: <list(1)> {'file': 'File:VMware HQ campus 3401 Hillview e...
#   infobox: <dict(20)> name, logo, image_caption, type, traded_as, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:VMware
#   label: VMware Inc.
#   labels: <dict(68)> P2003, P31, P646, Q47265, Q13677, P1454, P240...
#   length: 58,669
#   links: <list(218)> API, Address space, Adobe Inc, AirWatch, Amad...
#   modified: <dict(2)> page, wikidata
#   pageid: 312018
#   parsetree: <str(76940)> <root><template><title>short description...
#   random: Robert Crowther
#   redirects: <list(31)> {'pageid': 1546811, 'ns': 0, 'title': 'Vmw...
#   requests: <list(7)> query, parse, wikidata, labels, labels, rest...
#   title: VMware
#   url: https://en.wikipedia.org/wiki/VMware
#   url_raw: https://en.wikipedia.org/wiki/VMware?action=raw
#   watchers: 357
#   what: business
#   wikibase: Q11407
#   wikidata: <dict(48)> Commons category (P373), instance of (P31),...
#   wikidata_pageid: 12922
#   wikidata_url: https://www.wikidata.org/wiki/Q11407
#   wikitext: <str(58217)> {{short description|Multi-cloud service p...
# }
# en.wikipedia.org (parse) VMware
# [2022-01-20 10:08:27-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[8]': Finished task run for task with final state: 'Success'
# Robin Hood (1912 film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(12)> name, image, caption, director, producer, wr...
#   pageid: 15110213
#   parsetree: <str(5776)> <root><template><title>short description<...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (1912 film)
#   wikibase: Q3939269
#   wikidata_url: https://www.wikidata.org/wiki/Q3939269
#   wikitext: <str(3989)> {{short description|1912 film}}{{Infobox f...
# }
# en.wikipedia.org (parse) Robin Hood (1922 film)
# www.wikidata.org (labels) Q7014241|Q1196955|P856|P2002|P910|P1451...
# VMware (en) data
# {
#   infobox: <dict(20)> name, logo, image_caption, type, traded_as, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:VMware
#   pageid: 312018
#   parsetree: <str(76940)> <root><template><title>short description...
#   requests: <list(1)> parse
#   title: VMware
#   wikibase: Q11407
#   wikidata_url: https://www.wikidata.org/wiki/Q11407
#   wikitext: <str(58217)> {{short description|Multi-cloud service p...
# }
# en.wikipedia.org (imageinfo) File:Douglas Fairbanks Robin Hood 19...
# Douglas Fairbanks in Robin Hood (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Douglas F...
#   infobox: <dict(17)> name, image, director, writer, producer, sta...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 1089042
#   parsetree: <str(13264)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Douglas Fairbanks in Robin Hood
#   wikibase: Q2159851
#   wikidata_url: https://www.wikidata.org/wiki/Q2159851
#   wikitext: <str(9999)> {{Short description|1922 film by Allan Dwa...
# }
# en.wikipedia.org (parse) Robin Hood (1953 TV series)
# Robin Hood (1953 TV series) (en) data
# {
#   pageid: 11936449
#   parsetree: <str(3077)> <root><template><title>distinguish</title...
#   requests: <list(1)> parse
#   title: Robin Hood (1953 TV series)
#   wikibase: Q7352490
#   wikidata_url: https://www.wikidata.org/wiki/Q7352490
#   wikitext: <str(2329)> {{distinguish|text=the better-known 1955-5...
# }
# en.wikipedia.org (parse) Robin Hood (1973 film)
# www.wikidata.org (labels) P2013|Q2858615|Q1366075|P8687|Q778575|Q...
# en.wikipedia.org (imageinfo) File:Robinhood 1973 poster.png
# Robin Hood (1973 film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robinhood...
#   infobox: <dict(18)> name, image, caption, director, producer, st...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 982180
#   parsetree: <str(52621)> <root><template><title>Redirect</title><...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (1973 film)
#   wikibase: Q19090
#   wikidata_url: https://www.wikidata.org/wiki/Q19090
#   wikitext: <str(39821)> {{Redirect|Robin Hood (Disney)|the charac...
# }
# en.wikipedia.org (parse) Robin Hood (1990 TV series)
# www.wikidata.org (labels) Q4830453|P112|P3347|Q1581165|P4342
# en.wikipedia.org (restbase) /page/summary/Hitachi
# en.wikipedia.org (imageinfo) File:Nippon Life Insurance Company,M...
# Hitachi (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   aliases: <list(3)> Hitachi, Ltd., Kabushiki-gaisha Hitachi Seisa...
#   assessments: <dict(8)> Japan, Companies, Brands, Trains, Computi...
#   claims: <dict(53)> P373, P31, P112, P214, P244, P349, P910, P646...
#   description: Japanese multinational engineering and electronics ...
#   exhtml: <str(475)> <p><b>Hitachi, Ltd.</b> is a Japanese multina...
#   exrest: <str(434)> Hitachi, Ltd. is a Japanese multinational con...
#   extext: <str(769)> **Hitachi, Ltd.** (Japanese pronunciation: [ç...
#   extract: <str(902)> <p><b>Hitachi, Ltd.</b> (<small>Japanese pro...
#   image: <list(8)> {'kind': 'query-pageimage', 'file': 'File:Nippo...
#   infobox: <dict(27)> name, native_name, romanized_name, native_na...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   label: Hitachi
#   labels: <dict(105)> Q7014241, Q1196955, P856, P2002, P910, P1451...
#   length: 50,188
#   links: <list(824)> 5Zigen, A'PEXi, ABB Group, AEG, AEON (company...
#   modified: <dict(2)> page, wikidata
#   pageid: 188676
#   parsetree: <str(64424)> <root><template><title>short description...
#   random: Qeqertarsuaq Island (Karrat Fjord)
#   redirects: <list(49)> {'pageid': 720668, 'ns': 0, 'title': 'Hita...
#   requests: <list(9)> query, query, parse, wikidata, labels, label...
#   title: Hitachi
#   url: https://en.wikipedia.org/wiki/Hitachi
#   url_raw: https://en.wikipedia.org/wiki/Hitachi?action=raw
#   watchers: 181
#   what: business
#   wikibase: Q53238
#   wikidata: <dict(53)> Commons category (P373), instance of (P31),...
#   wikidata_pageid: 55685
#   wikidata_url: https://www.wikidata.org/wiki/Q53238
#   wikitext: <str(49739)> {{short description|Japanese multinationa...
# }
# en.wikipedia.org (parse) Hitachi
# Robin Hood (1990 TV series) (en) data
# {
#   infobox: <dict(3)> name, ja_kanji, ja_romaji
#   pageid: 4072460
#   parsetree: <str(12954)> <root><template><title>Short description...
#   requests: <list(1)> parse
#   title: Robin Hood (1990 TV series)
#   wikibase: Q2092998
#   wikidata_url: https://www.wikidata.org/wiki/Q2092998
#   wikitext: <str(9911)> {{Short description|Italian-Japanese anime...
# }
# en.wikipedia.org (parse) Robin Hood (1991 British film)
# en.wikipedia.org (imageinfo) File:Nippon Life Insurance Company,M...
# Hitachi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nippon Li...
#   infobox: <dict(27)> name, native_name, romanized_name, native_na...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 188676
#   parsetree: <str(64424)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Hitachi
#   wikibase: Q53238
#   wikidata_url: https://www.wikidata.org/wiki/Q53238
#   wikitext: <str(49739)> {{short description|Japanese multinationa...
# }
# [2022-01-20 10:08:30-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[9]': Finished task run for task with final state: 'Success'
# en.wikipedia.org (imageinfo) File:Robin Hood (1991 film) cover.jpg
# Robin Hood (1991 British film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(18)> name, image, caption, director, producer, sc...
#   pageid: 6309072
#   parsetree: <str(11699)> <root><template><title>for</title><part>...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (1991 British film)
#   wikibase: Q689658
#   wikidata_url: https://www.wikidata.org/wiki/Q689658
#   wikitext: <str(8304)> {{for|the 1991 film starring Kevin Costner...
# }
# en.wikipedia.org (parse) Robin Hood (2006 TV series)
# en.wikipedia.org (imageinfo) File:Robinhoods2titlescreen.jpg
# Robin Hood (2006 TV series) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robinhood...
#   infobox: <dict(21)> name, image, caption, genre, creator, starri...
#   iwlinks: <list(1)> https://en.wikiquote.org/wiki/Robin_Hood_(BBC)
#   pageid: 4017773
#   parsetree: <str(31340)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (2006 TV series)
#   wikibase: Q40028
#   wikidata_url: https://www.wikidata.org/wiki/Q40028
#   wikitext: <str(25848)> {{Use dmy dates|date=February 2021}}{{Use...
# }
# en.wikipedia.org (parse) Robin Hood (2009 film)
# en.wikipedia.org (imageinfo) File:Robin Hood Malayalam.jpg
# Robin Hood (2009 film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(15)> name, image, caption, director, producer, wr...
#   pageid: 21652487
#   parsetree: <str(7164)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (2009 film)
#   wikibase: Q7352489
#   wikidata_url: https://www.wikidata.org/wiki/Q7352489
#   wikitext: <str(4885)> {{Use dmy dates|date=April 2020}}{{More ci...
# }
# en.wikipedia.org (parse) Robin Hood (2010 film)
# en.wikipedia.org (imageinfo) File:Robin Hood 2010 poster.jpg
# Robin Hood (2010 film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(19)> name, image, caption, director, producer, sc...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 13713239
#   parsetree: <str(70734)> <root><template><title>Short description...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (2010 film)
#   wikibase: Q223559
#   wikidata_url: https://www.wikidata.org/wiki/Q223559
#   wikitext: <str(58141)> {{Short description|2010 action film by R...
# }
# en.wikipedia.org (parse) Robin Hood (2018 film)
# en.wikipedia.org (imageinfo) File:Robin Hood (2018 film poster).png
# Robin Hood (2018 film) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(20)> name, image, border, caption, director, prod...
#   pageid: 46912362
#   parsetree: <str(34111)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (2018 film)
#   wikibase: Q28811584
#   wikidata_url: https://www.wikidata.org/wiki/Q28811584
#   wikitext: <str(28404)> {{short description|2018 Action-adventure...
# }
# en.wikipedia.org (parse) Robin Hood (DC Comics)
# en.wikipedia.org (imageinfo) File:Robinhooddcu0.jpg
# Robin Hood (DC Comics) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robinhood...
#   infobox: <dict(14)> image, converted, caption, character_name, r...
#   pageid: 28035697
#   parsetree: <str(12574)> <root><template><title>Infobox comics ch...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (DC Comics)
#   wikibase: Q7352491
#   wikidata_url: https://www.wikidata.org/wiki/Q7352491
#   wikitext: <str(8979)> {{Infobox comics character <!--Wikipedia:W...
# }
# en.wikipedia.org (parse) Robin Hood (De Koven opera)
# Robin Hood (De Koven opera) (en) data
# {
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 22749489
#   parsetree: <str(8465)> <root><template><title>italic title</titl...
#   requests: <list(1)> parse
#   title: Robin Hood (De Koven opera)
#   wikibase: Q7352497
#   wikidata_url: https://www.wikidata.org/wiki/Q7352497
#   wikitext: <str(7394)> {{italic title}}'''''Robin Hood''''' is a ...
# }
# en.wikipedia.org (parse) Robin Hood (Disney character)
# en.wikipedia.org (imageinfo) File:Robin Hood Disney character.png
# Robin Hood (Disney character) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Robin Hoo...
#   infobox: <dict(13)> color, name, series, image, caption, first_m...
#   pageid: 50693271
#   parsetree: <str(10907)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Robin Hood (Disney character)
#   wikibase: Q3437147
#   wikidata_url: https://www.wikidata.org/wiki/Q3437147
#   wikitext: <str(8692)> {{short description|Disney character}}{{In...
# }
# en.wikipedia.org (parse) Robin Hood (Once Upon a Time)
# List of Once Upon a Time characters (en) data
# {
#   infobox: <dict(1)> border
#   pageid: 33751496
#   parsetree: <str(188399)> <root><template><title>short descriptio...
#   requests: <list(1)> parse
#   title: List of Once Upon a Time characters
#   wikibase: Q3900260
#   wikidata_url: https://www.wikidata.org/wiki/Q3900260
#   wikitext: <str(146206)> {{short description|Wikipedia list artic...
# }
# en.wikipedia.org (parse) Robin Hood (Tippett opera)
# Robin Hood (Tippett opera) (en) data
# {
#   infobox: <dict(8)> name, type, composer, librettist, language, b...
#   pageid: 20011801
#   parsetree: <str(3727)> <root><template><title>Infobox opera</tit...
#   requests: <list(1)> parse
#   title: Robin Hood (Tippett opera)
#   wikibase: Q7352499
#   wikidata_url: https://www.wikidata.org/wiki/Q7352499
#   wikitext: <str(2554)> {{Infobox opera| name = Robin Hood| type =...
# }
# en.wikipedia.org (parse) Robin Hood (album)
# [2022-01-20 10:08:35-0500] INFO - prefect.TaskRunner | Task 'get_wiki_improve[70]': Finished task run for task with final state: 'Success'
# [2022-01-20 10:08:36-0500] INFO - prefect.TaskRunner | Task 'show_dataframe_task': Starting task run...
# [2022-01-20 10:08:36-0500] INFO - prefect.TaskRunner | Task 'show_dataframe_task': Finished task run for task with final state: 'Success'
# [2022-01-20 10:08:36-0500] INFO - prefect.FlowRunner | Flow run SUCCESS: all reference tasks succeeded
# [<Task: show_dataframe_task>]
# <Task: show_dataframe_task>
# Robin Hood (album) (en) data
# {
#   infobox: <dict(8)> name, type, artist, released, genre, length, ...
#   pageid: 8890924
#   parsetree: <str(3899)> <root><template><title>Unreferenced</titl...
#   requests: <list(1)> parse
#   title: Robin Hood (album)
#   wikibase: Q7352492
#   wikidata_url: https://www.wikidata.org/wiki/Q7352492
#   wikitext: <str(2340)> {{Unreferenced|date=January 2007}}{{Infobo...
# }

# %%
new_company = pd.concat([new_company.reset_index(drop = True), wiki_result], axis=1)
columnname = new_company.columns
new_company['size_wiki'] = new_company.apply(lambda x: find_size(x, columnname),axis=1).apply(process_size)

# %%
new_company = new_company[['refined_name','policy','link','story','size_wiki']]

# %%
new_company.groupby('policy').count()
# Out:
#                        refined_name  link  story  size_wiki
# policy
# Fully Remote                      3     3      3          1
# Hybrid/Optional                   2     2      2          2
# Hybrid/Partial                    6     6      6          4
# Optional                         13    13     13         11
# Optional/Partial                  1     1      1          1
# Partial                          17    17     17         14
# Partial/Optional                  2     2      2          2
# Partial/Remote First              1     1      1          1
# Partial                           1     1      1          1
# Remote First                     22    22     22         11
# Remote First/Hybrid               2     2      2          2
# Remote First/Optional             1     1      1          1
# Remote FirstOptional              1     1      1          0

# %%
# new_company.to_excel('Companies with Remote Programs JH Edit.xlsx')
